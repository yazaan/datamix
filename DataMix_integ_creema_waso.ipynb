# %%
# !pip install beautifulsoup4

# %%
# !pip install --upgrade matplotlib
# Out:
# Requirement already up-to-date: matplotlib in ./opt/anaconda3/lib/python3.7/site-packages (3.4.1)
# ...

# %%
from bs4 import BeautifulSoup
import bs4
import re
import os

# %%
# スクレイピング対象のhtmlファイルからsoupを作成
soup = bs4.BeautifulSoup(open('html/wa_2_5.html'), 'html.parser')
soup
# Out:
# <html lang="ja" xmlns:fb="http://ogp.me/ns/fb#" xmlns:og="http://ogp.me/ns#"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="(c) CREEMA LTD." name="copyright"/>
# <meta content="洗える帯揚げ 高級レース化繊 選べる6色【ﾓﾀﾞﾝﾀﾞｲﾔ柄ﾚｰｽ】絶対可愛いので浴衣に小紋に大活躍です！ポリ100％" name="title"/>
# <meta content="●洗える帯揚げ 高級レース化繊 選べる6色【ﾓﾀﾞﾝﾀﾞｲﾔ柄ﾚｰｽ】●約180ｃｍ×約30ｃｍ ﾎﾟﾘｴｽﾃﾙ 100％●色をお選びください1　ﾃｰﾙｸﾞﾘ..." name="description"/>
# <meta content="ハンドメイド, 手仕事, 手作り, 販売, 出品, クリーマ, Creema, アクセサリー, ジュエリー, プレゼント, 店舗, Creema Store, クリーマストア" name="keywords"/>
# <title>洗える帯揚げ 高級レース化繊 選べる6色【ﾓﾀﾞﾝﾀﾞｲﾔ柄ﾚｰｽ】絶対可愛いので浴衣に小紋に大活躍です！ポリ100％ 和装・和小物 pal+ 通販｜Creema(クリーマ) ハンドメイド・手作り・クラフト作品の販売サイト</title>
# <link href="https://media-01.creema.net/assets/20210409-155410/vendor/slick/slick.css" rel="stylesheet"/>
# <link href="https://media-01.creema.net/assets/20210409-155410/vendor/slick/slick-theme.css" rel="stylesheet"/>
# ...

# %%
title = soup.find_all("h2", attrs={"class", "c-heading-rhombus c-heading-rhombus--olive p-item-detail-title"})[0].get_text(strip=True)
title
# Out:
# '洗える帯揚げ 高級レース化繊 選べる6色【ﾓﾀﾞﾝﾀﾞｲﾔ柄ﾚｰｽ】絶対可愛いので浴衣に小紋に大活躍です！ポリ100％'

# %%
price_text = soup.find_all("div", attrs={"class", "p-item-detail-info__item p-item-detail-info__item--price"})[0].get_text()
price = re.sub("\\D", "", price_text)
price
# Out:
# '2880'

# %%
favorite_text = soup.find_all("span", attrs={"class", "js-like-item-number"})[0].get_text()
favorite = re.sub("\\D", "", favorite_text)
favorite
# Out:
# '71'

# %%
item_text = soup.find("div", attrs={"class", "p-item-detail-info__item p-item-detail-info__item--right"}).text
item = re.sub("\\D", "", item_text)
item
# Out:
# '2'

# %%
material = soup.find_all("ul", attrs={"class", "p-item-detail-tag__list u-clearfix"})[0].get_text(strip=True)
material
# Out:
# 'ファッション和装・和小物和装小物（帯・半襟）その他柄もの'

# %%
image = soup.select('#js-item-detail > article > div.p-item-detail-gallery.u-clearfix > div.p-item-detail-centerpiece > div > img')[0].get('src')
image
# Out:
# 'https://media-01.creema.net/user/4783532/exhibits/10278552/0_4ea2d3fc54a7a90466fe58f23369503c_583x585.jpg'

# %%
pv_text = soup.find_all("div", attrs={"class", "p-item-detail-pv"})[0].get_text()
pv = re.sub("\\D", "", pv_text)
pv
# Out:
# '992'

# %%
follower_text = soup.find_all("a", attrs={"class", "js-follower-count"})[0].get_text()
follower = re.sub("\\D", "", follower_text)
follower
# Out:
# '117'

# %%
evaluation_text = soup.select("#js-creator-rating-average > span > a")[0].get_text()
evaluation = re.sub("\\D", "", evaluation_text)
evaluation
# Out:
# '54'

# %%
import os

path_list = os.listdir('html')

result=[]
for path in path_list:
    
    try:
        soup = bs4.BeautifulSoup(open(f'html/{path}'), 'html.parser')
    except:
        print(ex)
        
    try:
        title = soup.find_all("h2", attrs={"class", "c-heading-rhombus c-heading-rhombus--olive p-item-detail-title"})[0].get_text(strip=True)
    except:
        title = ''

    try:
        price_text = soup.find_all("div", attrs={"class", "p-item-detail-info__item p-item-detail-info__item--price"})[0].get_text()
        price = re.sub("\\D", "", price_text)
    except:
        price = ''
    
    try:        
        favorite_text = soup.find_all("span", attrs={"class", "js-like-item-number"})[0].get_text()
        favorite = re.sub("\\D", "", favorite_text)
    except:
        favorite = ''
    
    try:
        item_text = soup.find("div", attrs={"class", "p-item-detail-info__item p-item-detail-info__item--right"}).text
        item = re.sub("\\D", "", item_text)
    except:
        item = ''
        
    try:
        pv_text = soup.find_all("div", attrs={"class", "p-item-detail-pv"})[0].get_text()
        pv = re.sub("\\D", "", pv_text)
    except:
        pv = ''
        
    try:
        follower_text = soup.find_all("a", attrs={"class", "js-follower-count"})[0].get_text()
        follower = re.sub("\\D", "", follower_text)
    except:
        follower = ''
    
        
    try:
        evaluation_text = soup.select("#js-creator-rating-average > span > a")[0].get_text()
        evaluation = re.sub("\\D", "", evaluation_text)
    except:
        evaluation = ''
    
        
    try:
        image = soup.select('#js-item-detail > article > div.p-item-detail-gallery.u-clearfix > div.p-item-detail-centerpiece > div > img')[0].get('src')
    except Exception as ex:
        print(ex)
    
    result.append({"title": title, "price":price, "favorite": favorite, "item":item, "pv":pv, "image":image, "follower":follower,"evaluation":evaluation })
# Out:
# list index out of range
# list index out of range
# list index out of range
# list index out of range

# %%
result
# Out:
# [{'title': '【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/\u3000よろけ縞（シルバーxグレーxブルーxホワイトライン）',
#   'price': '18000',
#   'favorite': '34',
#   'item': '',
#   'pv': '660',
#   'image': 'https://media-01.creema.net/user/3463610/exhibits/9973608/1_e0731534ba71888d5f5550cf43bffeb2_583x585.jpg',
#   'follower': '134',
#   'evaluation': '22'},
#  {'title': '小紋（薔薇の花ローケツ染）',
#   'price': '324000',
#   'favorite': '19',
#   'item': '',
#   'pv': '2058',
#   'image': 'https://media-01.creema.net/user/196958/exhibits/1381976/1_5abadf817f96d6480e5f596056e89b37cd6d6cbf_583x585.jpg',
#   'follower': '307',
#   'evaluation': '51'},
#  {'title': '●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺',
#   'price': '8000',
#   'favorite': '17',
#   'item': '',
#   'pv': '268',
#   'image': 'https://media-01.creema.net/user/88989/exhibits/8273364/0_773208f583f653fe249f8f1b8dfb06de_583x585.jpg',
#   'follower': '2721',
#   'evaluation': '1019'},
#  {'title': '注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製',
#   'price': '1100',
# ...

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

matplotlib.style.use('ggplot')

# %%
df.describe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-ad7f9ecfd38f> in <module>
# ----> 1 df.describe
#
# NameError: name 'df' is not defined

# %%
train = pd.DataFrame(result)
train
# Out:
#                                                   title   price favorite item  \
# 0     【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000       34
# 1                                         小紋（薔薇の花ローケツ染）  324000       19
# 2                  ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000       17
# 3      注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100       41   10
# 4                                         七宝焼き帯留め(2228)    5500        4
# ...                                                 ...     ...      ...  ...
# 9715                                    ダリアの帯留め　ペールオレンジ    1200        8
# 9716                           帯留◇水引梅◇青松葉 藍 金 ベージュ 裏葉 ◇    1500       20    2
# 9717  洗える着物　夏着物　波に浮かぶ小花が涼し気　ポリエステル単衣トールサイス　裄68ｃｍ　和裁師...    6980       69
# 9718                               東京切子帯留め　お太鼓　麻の葉　クリアー   19800       47    1
# 9719                                           つまみ細工半くす    1800        3
#
# ...

# %%
train.to_csv('creema_waso_bs4¥2.csv',index=False)

# %%
train = pd.read_csv("Downloads/creema_waso_bs4¥2.csv")
train.head()
# Out:
#                                                title     price  favorite  \
# 0  【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000.0      34.0
# 1                                      小紋（薔薇の花ローケツ染）  324000.0      19.0
# 2               ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000.0      17.0
# 3   注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100.0      41.0
# 4                                      七宝焼き帯留め(2228)    5500.0       4.0
#
#    item      pv                                              image  follower  \
# 0   NaN   660.0  https://media-01.creema.net/user/3463610/exhib...     134.0
# 1   NaN  2058.0  https://media-01.creema.net/user/196958/exhibi...     307.0
# 2   NaN   268.0  https://media-01.creema.net/user/88989/exhibit...    2721.0
# 3  10.0   918.0  https://media-01.creema.net/user/4262893/exhib...     271.0
# 4   NaN    59.0  https://media-01.creema.net/user/431375/exhibi...    2657.0
#
#    evaluation
# 0        22.0
# 1        51.0
# 2      1019.0
# ...

# %%
img = df["image"]
img[0]
# Out:
# 'https://media-01.creema.net/user/4262893/exhibits/9330919/0_49fd7e4a4380731712eefa37833f6311_583x585.jpg'

# %%
train['price'] = pd.to_numeric(train['price'])
train['favorite'] = pd.to_numeric(train['favorite'])
train['item'] = pd.to_numeric(train['item'])
train['pv'] = pd.to_numeric(train['pv'])
train['price']
# Out:
# 0        18000.0
# 1       324000.0
# 2         8000.0
# 3         1100.0
# 4         5500.0
#           ...
# 9715      1200.0
# 9716      1500.0
# 9717      6980.0
# 9718     19800.0
# 9719      1800.0
# Name: price, Length: 9720, dtype: float64

# %%
train['item'].all
# Out:
# <bound method Series.all of 0        NaN
# 1        NaN
# 2        NaN
# 3       10.0
# 4        NaN
#         ...
# 9715     NaN
# 9716     2.0
# 9717     NaN
# 9718     1.0
# 9719     NaN
# Name: item, Length: 9720, dtype: float64>

# %%
train['item'].hist()

# %%
train['price'].hist()

# %%
train['favorite'].hist()

# %%
train['pv'].hist()

# %%
train['follower'].hist()

# %%
train['evaluation'].hist()

# %%
col_names = train.columns
for col_name in col_names:
    missing_num = sum(pd.isnull(train[col_name]))
    print(col_name, '; # of missing record: ', missing_num)
# Out:
# title ; # of missing record:  4
# price ; # of missing record:  0
# favorite ; # of missing record:  0
# item ; # of missing record:  0
# pv ; # of missing record:  0
# image ; # of missing record:  0
# follower ; # of missing record:  0
# evaluation ; # of missing record:  0

# %%
pd.isnull(train["price"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9715    False
# 9716    False
# 9717    False
# 9718    False
# 9719    False
# Name: price, Length: 9720, dtype: bool

# %%
train["price"].dtype
# Out:
# dtype('float64')

# %%
sum(pd.isnull(train["price"]))
# Out:
# 27

# %%
train["price"].isnull().sum()
# Out:
# 27

# %%
train["price"].fillna(0, inplace=True)
train.head()
# Out:
#                                                title     price  favorite  \
# 0  【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000.0      34.0
# 1                                      小紋（薔薇の花ローケツ染）  324000.0      19.0
# 2               ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000.0      17.0
# 3   注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100.0      41.0
# 4                                      七宝焼き帯留め(2228)    5500.0       4.0
#
#    item      pv                                              image  follower  \
# 0   NaN   660.0  https://media-01.creema.net/user/3463610/exhib...     134.0
# 1   NaN  2058.0  https://media-01.creema.net/user/196958/exhibi...     307.0
# 2   NaN   268.0  https://media-01.creema.net/user/88989/exhibit...    2721.0
# 3  10.0   918.0  https://media-01.creema.net/user/4262893/exhib...     271.0
# 4   NaN    59.0  https://media-01.creema.net/user/431375/exhibi...    2657.0
#
#    evaluation
# 0        22.0
# 1        51.0
# 2      1019.0
# ...

# %%
train["favorite"].fillna(0, inplace=True)
train.head()
# Out:
#                                                title     price  favorite  \
# 0  【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000.0      34.0
# 1                                      小紋（薔薇の花ローケツ染）  324000.0      19.0
# 2               ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000.0      17.0
# 3   注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100.0      41.0
# 4                                      七宝焼き帯留め(2228)    5500.0       4.0
#
#    item      pv                                              image  follower  \
# 0   NaN   660.0  https://media-01.creema.net/user/3463610/exhib...     134.0
# 1   NaN  2058.0  https://media-01.creema.net/user/196958/exhibi...     307.0
# 2   NaN   268.0  https://media-01.creema.net/user/88989/exhibit...    2721.0
# 3  10.0   918.0  https://media-01.creema.net/user/4262893/exhib...     271.0
# 4   NaN    59.0  https://media-01.creema.net/user/431375/exhibi...    2657.0
#
#    evaluation
# 0        22.0
# 1        51.0
# 2      1019.0
# ...

# %%
train["item"].fillna(0, inplace=True)
train.head()
# Out:
#                                                title     price  favorite  \
# 0  【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000.0      34.0
# 1                                      小紋（薔薇の花ローケツ染）  324000.0      19.0
# 2               ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000.0      17.0
# 3   注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100.0      41.0
# 4                                      七宝焼き帯留め(2228)    5500.0       4.0
#
#    item      pv                                              image  follower  \
# 0   0.0   660.0  https://media-01.creema.net/user/3463610/exhib...     134.0
# 1   0.0  2058.0  https://media-01.creema.net/user/196958/exhibi...     307.0
# 2   0.0   268.0  https://media-01.creema.net/user/88989/exhibit...    2721.0
# 3  10.0   918.0  https://media-01.creema.net/user/4262893/exhib...     271.0
# 4   0.0    59.0  https://media-01.creema.net/user/431375/exhibi...    2657.0
#
#    evaluation
# 0        22.0
# 1        51.0
# 2      1019.0
# ...

# %%
train["pv"].fillna(0, inplace=True)
train.head()
# Out:
#                                                title     price  favorite  \
# 0  【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000.0      34.0
# 1                                      小紋（薔薇の花ローケツ染）  324000.0      19.0
# 2               ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000.0      17.0
# 3   注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100.0      41.0
# 4                                      七宝焼き帯留め(2228)    5500.0       4.0
#
#    item      pv                                              image  follower  \
# 0   0.0   660.0  https://media-01.creema.net/user/3463610/exhib...     134.0
# 1   0.0  2058.0  https://media-01.creema.net/user/196958/exhibi...     307.0
# 2   0.0   268.0  https://media-01.creema.net/user/88989/exhibit...    2721.0
# 3  10.0   918.0  https://media-01.creema.net/user/4262893/exhib...     271.0
# 4   0.0    59.0  https://media-01.creema.net/user/431375/exhibi...    2657.0
#
#    evaluation
# 0        22.0
# 1        51.0
# 2      1019.0
# ...

# %%
train["follower"].fillna(0, inplace=True)
train.head()
# Out:
#                                                title     price  favorite  \
# 0  【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000.0      34.0
# 1                                      小紋（薔薇の花ローケツ染）  324000.0      19.0
# 2               ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000.0      17.0
# 3   注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100.0      41.0
# 4                                      七宝焼き帯留め(2228)    5500.0       4.0
#
#    item      pv                                              image  follower  \
# 0   0.0   660.0  https://media-01.creema.net/user/3463610/exhib...     134.0
# 1   0.0  2058.0  https://media-01.creema.net/user/196958/exhibi...     307.0
# 2   0.0   268.0  https://media-01.creema.net/user/88989/exhibit...    2721.0
# 3  10.0   918.0  https://media-01.creema.net/user/4262893/exhib...     271.0
# 4   0.0    59.0  https://media-01.creema.net/user/431375/exhibi...    2657.0
#
#    evaluation
# 0        22.0
# 1        51.0
# 2      1019.0
# ...

# %%
train["evaluation"].fillna(0, inplace=True)
train.head()
# Out:
#                                                title     price  favorite  \
# 0  【リバーシブル半幅帯】ダマクス（ターコイズxダークブラウン）/　よろけ縞（シルバーxグレーx...   18000.0      34.0
# 1                                      小紋（薔薇の花ローケツ染）  324000.0      19.0
# 2               ●●お羊屋USAコットンオーナメント風スノーフレーク柄半幅帯新品リバ長尺    8000.0      17.0
# 3   注染手ぬぐい 【ギョウザ】 喜多屋商店 てぬぐい 餃子 餃子のまち 浜松餃子 宇都宮餃子 日本製    1100.0      41.0
# 4                                      七宝焼き帯留め(2228)    5500.0       4.0
#
#    item      pv                                              image  follower  \
# 0   0.0   660.0  https://media-01.creema.net/user/3463610/exhib...     134.0
# 1   0.0  2058.0  https://media-01.creema.net/user/196958/exhibi...     307.0
# 2   0.0   268.0  https://media-01.creema.net/user/88989/exhibit...    2721.0
# 3  10.0   918.0  https://media-01.creema.net/user/4262893/exhib...     271.0
# 4   0.0    59.0  https://media-01.creema.net/user/431375/exhibi...    2657.0
#
#    evaluation
# 0        22.0
# 1        51.0
# 2      1019.0
# ...

# %%
import matplotlib.pyplot as plt
target_col = "item"
feature_cols = ["price","favorite","pv","follower","evaluation"]

# %%
train[feature_cols].head()
# Out:
#       price  favorite      pv  follower  evaluation
# 0   18000.0      34.0   660.0     134.0        22.0
# 1  324000.0      19.0  2058.0     307.0        51.0
# 2    8000.0      17.0   268.0    2721.0      1019.0
# 3    1100.0      41.0   918.0     271.0       211.0
# 4    5500.0       4.0    59.0    2657.0       831.0

# %%
train[target_col].head()
# Out:
# 0     0.0
# 1     0.0
# 2     0.0
# 3    10.0
# 4     0.0
# Name: item, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X = train[feature_cols]
y = train[target_col]

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1234)

# %%
print('X_train_val Features Shape: ', X_train_val.shape)
print('y_train_val Target Shape: ', y_train_val.shape)
print('X_test Features Shape: ', X_test.shape)
print('y_test Target Shape: ', y_test.shape)
# Out:
# X_train_val Features Shape:  (6804, 5)
# y_train_val Target Shape:  (6804,)
# X_test Features Shape:  (2916, 5)
# y_test Target Shape:  (2916,)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.3, random_state=1234)

# %%
print('X_train Features Shape: ', X_train.shape)
print('y_train Target Shape: ', y_train.shape)
print('X_val Features Shape: ', X_val.shape)
print('y_val Target Shape: ', y_val.shape)
# Out:
# X_train Features Shape:  (4762, 5)
# y_train Target Shape:  (4762,)
# X_val Features Shape:  (2042, 5)
# y_val Target Shape:  (2042,)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
y_pred = lm.predict(X_val)
lm_mse = mean_squared_error(y_val, y_pred)
lm_rmse = print('LinerRegression RMSE: ', round(np.sqrt(lm_mse), 3))
# Out:
# LinerRegression RMSE:  1.579

# %%
train[['item','price']].corr()
# Out:
#            item     price
# item   1.000000 -0.027706
# price -0.027706  1.000000

# %%
train[['item','favorite']].corr()
# Out:
#               item  favorite
# item      1.000000  0.609982
# favorite  0.609982  1.000000

# %%
train[['item','pv']].corr()
# Out:
#           item        pv
# item  1.000000  0.419692
# pv    0.419692  1.000000

# %%
train[['item','follower']].corr()
# Out:
#               item  follower
# item      1.000000  0.211612
# follower  0.211612  1.000000

# %%
train[['item','evaluation']].corr()
# Out:
#                 item  evaluation
# item        1.000000    0.216137
# evaluation  0.216137    1.000000

# %%
train.corr().loc[:, ['item']].abs().sort_values('item', ascending = False)
# Out:
#                 item
# item        1.000000
# favorite    0.609982
# pv          0.419692
# evaluation  0.216137
# follower    0.211612
# price       0.027706

# %%
# 標準化する
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X = ss.fit_transform(X)

# %%
# 自由度調整済み決定係数関数を定義する
def adjusted(score, n_sample, n_features):
    adjusted_score = 1 - (1 - score) * ((n_sample - 1) / (n_sample - n_features - 1))
    return adjusted_score

# %%
# モデルの評価
print('adjusted R^2')
print('train: %.3f' % adjusted(lm.score(X_train, y_train), len(y_train),X_train.shape[1]))
print('test : %.3f' % adjusted(lm.score(X_test, y_test), len(y_test), X_test.shape[1]))
# Out:
# adjusted R^2
# train: 0.380
# test : 0.277

# %%
feature_cols = ["favorite","pv"]

# %%
X = train[feature_cols]
y = train[target_col]

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1234)

# %%
print('X_train_val Features Shape: ', X_train_val.shape)
print('y_train_val Target Shape: ', y_train_val.shape)
print('X_test Features Shape: ', X_test.shape)
print('y_test Target Shape: ', y_test.shape)
# Out:
# X_train_val Features Shape:  (6804, 2)
# y_train_val Target Shape:  (6804,)
# X_test Features Shape:  (2916, 2)
# y_test Target Shape:  (2916,)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.3, random_state=1234)

# %%
print('X_train Features Shape: ', X_train.shape)
print('y_train Target Shape: ', y_train.shape)
print('X_val Features Shape: ', X_val.shape)
print('y_val Target Shape: ', y_val.shape)
# Out:
# X_train Features Shape:  (4762, 2)
# y_train Target Shape:  (4762,)
# X_val Features Shape:  (2042, 2)
# y_val Target Shape:  (2042,)

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
y_pred = lm.predict(X_val)
lm_mse = mean_squared_error(y_val, y_pred)
lm_rmse = print('LinerRegression RMSE: ', round(np.sqrt(lm_mse), 3))
# Out:
# LinerRegression RMSE:  1.603

# %%
def adjusted(score, n_sample, n_features):
    adjusted_score = 1 - (1 - score) * ((n_sample - 1) / (n_sample - n_features - 1))
    return adjusted_score

# %%
# モデルの評価
print('adjusted R^2')
print('train: %.3f' % adjusted(lm.score(X_train, y_train), len(y_train),X_train.shape[1]))
print('test : %.3f' % adjusted(lm.score(X_test, y_test), len(y_test), X_test.shape[1]))
# Out:
# adjusted R^2
# train: 0.362
# test : 0.380

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_val, y_pred)
round(mae,3)
# Out:
# 0.886

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_val, y_pred)
round(r2,3)
# Out:
# 0.472
